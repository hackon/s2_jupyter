# %%
import json
with open("brreg.json") as f:
  
  data = json.load(f)

# %%
a=( p['navn'] for p in data if p['navn'] == 'MONA ULLAH')

# %%
print(type(a))
# Out:
# <class 'generator'>

# %%
print(data[0]['naeringskode1']['kode'])
# Out:
# 74.300

# %%
res = dict()
for d in data:
  if 'naeringskode1' in d.keys() :
    key = d['naeringskode1']['kode']
    if key not in res.keys():
      res[key] = 1
    else:
      res[key] +=1


for key,item in reversed(sorted(res.items(), key= lambda item: item[1])):
  print(key, item)
# Out:
# 68.209 66146
# 94.991 65284
# 00.000 32353
# 41.200 27123
# 70.220 25262
# 90.011 24948
# 64.308 18244
# 71.129 16079
# 02.200 15693
# 41.109 15566
# 68.100 13573
# 62.010 13444
# 62.020 13305
# 86.211 13288
# 96.020 13034
# 86.909 12962
# 93.120 12894
# 85.599 12541
# 01.410 12269
# 49.410 12191
# 01.451 12009
# 01.110 11180
# 43.120 11138
# 43.320 11064
# 85.510 10335
# 68.320 9716
# 68.201 9355
# 90.031 9098
# 90.034 8962
# 49.320 8762
# 56.101 8639
# 97.000 8595
# 74.200 8283
# 03.111 8226
# 73.110 7287
# 43.990 7176
# 82.990 6966
# 45.200 6770
# 74.102 6483
# 81.210 6475
# 86.902 6397
# 59.110 6341
# 90.020 6250
# 71.121 6126
# 96.090 6045
# 94.910 5812
# 01.420 5674
# 43.210 5671
# 90.012 5629
# 47.990 5506
# 86.230 5402
# 43.221 4990
# 69.201 4933
# 01.190 4847
# 47.919 4818
# 43.341 4690
# 53.200 4638
# 81.101 4524
# 45.112 4328
# 94.200 4264
# 47.111 3892
# 74.101 3717
# 78.200 3601
# 86.905 3466
# 94.920 3427
# 71.112 3371
# 94.992 3320
# 33.120 3219
# 74.909 3118
# ...
